# %% [markdown]
# <a href="https://colab.research.google.com/github/rajatlamsal00977/Project-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We are going to define the different types of possible computational errors and their parameters along with their calculation formulae.

# %%
def abs_error(estimate, actualValue):
  return actualValue - estimate

def rlv_error(estimate, actualValue):
  return abs_error(estimate, actualValue)/actualValue

def appx_error(previousEstimate, currentEstimate):
  return currentEstimate - previousEstimate

def rlv_appxerror(previousEstimate, currentEstimate):
  return appx_error(previousEstimate, currentEstimate)/currentEstimate

# %% [markdown]
# We will compute the Taylor expansion of the function **f(X) = cosx** at a center **a = pi/2**.
# whose generalized form will be as shown in the equation below:
#
#
#
# $$
# f_n(x) = \sum_{i=0}^n  \frac{\left(-1\right)^{n+1}}1 *(1/(2n+1)!)
# \left(x-\frac \pi 2\right)^{2n+1}
# $$

# %% [markdown]
# For computational purpose we are going to **import math** package along with that we will be defining the **pi** and **squareroot** functions.

# %%
import math
pi = math.pi
sqrt2 = math.sqrt(2)


def Coefficient(degree):
  return (-1)**(math.floor(degree +1))/(math.factorial((2*degree) + 1))

def PolynomialTerm(degree, input):
  return Coefficient(degree)*(input-pi/2)**((2*degree) + 1)

def Polynomial(degree, input):
  sum = 0
  for i in range(0, degree+1):
    sum = sum + PolynomialTerm(i, input)
  return sum

# %% [markdown]
# We will now use the package **Plotly** inorder to table all of our value in a systematic way.

# %%
degree = [i for i in range(0,21)]
actualValues = [math.cos(pi/2+.1) for i in degree]
estimateValues = [Polynomial(n,pi/2+.1) for n in degree]
absError = [abs_error(estimateValues[i],actualValues[i]) for i in degree]
relError = [rlv_error(estimateValues[i],actualValues[i]) for i in degree]
apxError = [appx_error(estimateValues[i],estimateValues[i+1]) for i in range(0,19)]
relApxError = [rlv_appxerror(estimateValues[i],estimateValues[i+1]) for i in range (0,19)]

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Table(
                header=dict(values=['Degree', 'Actual Value', 'Estimated Value','Absolute Error','Relative Error','Approximate Error','Relative Approximate Error']),
                 cells=dict(values = [degree,actualValues,estimateValues,absError,relError,apxError,relApxError]))
                     ])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f95b968-51c5-468f-a3a8-70edd693f2cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f95b968-51c5-468f-a3a8-70edd693f2cf")) {
#                     Plotly.newPlot(
#                         '8f95b968-51c5-468f-a3a8-70edd693f2cf',
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange( 0,5,.001)
plt.scatter(pi/2,1/sqrt2)
plt.plot(x,Polynomial(5,x))
plt.plot(x, np.cos(x))
plt.title('Graph of Taylor Approximation Centered at ' r'$\frac{\pi}{2}$')
plt.legend(['5th Order Taylor Polynomial', 'cos Wave'])

plt.show()

# %%
x = np.arange( -8,10,.001)
plt.scatter(pi/2,1/sqrt2)
plt.plot(x,Polynomial(20,x))
plt.plot(x, np.cos(x))
plt.title('Graph of Taylor Approximation Centered at ' r'$\frac{\pi}{2}$')
plt.legend(['20th Order Taylor Polynomial', 'cos Wave'])

plt.show()
